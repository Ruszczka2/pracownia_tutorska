# %% [markdown]
# # Wykonanie metryki IoU względem Ground Truth

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Dodanie dźwięku przy długich komórkach
import subprocess
def play_sound():
    sound_file = '/mnt/d/Backup/INZ/msg.ogg'
    subprocess.run(['ffplay', '-nodisp', '-autoexit', sound_file], capture_output=True)

# %% [markdown]
# ## Pobranie danych

# %% [markdown]
# Ground Truth

# %%
ground_truth_172 = np.load('/mnt/d/Backup/MAGISTERSKIE/outputs/bboxes_normalized_172.npy')
ground_truth_2000 = np.load('/mnt/d/Backup/MAGISTERSKIE/outputs/bboxes_normalized_2000.npy')

print(ground_truth_172.shape)
print(ground_truth_2000.shape)
# Out:
# (172, 12)
# (2012, 12)

# %% [markdown]
# GroundedSAM

# %%
# Out:
# (172, 12)
# (2012, 12)

# %% [markdown]
# OpenAI

# %% [markdown]
# Dostrojone OpenAI
